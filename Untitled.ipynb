# %%
from queryarticles import  QueryArticleLoop

QueryArticleLoop("199701", "200801",1000)
# Out:
# [1997, 1]
# Directory contains more than 1000 articles
# [1997, 2]
# Directory contains more than 1000 articles
# [1997, 3]
# Directory contains more than 1000 articles
# [1997, 4]
# Directory contains more than 1000 articles
# [1997, 5]
# Directory contains more than 1000 articles
# [1997, 6]
# Directory contains more than 1000 articles
# [1997, 7]
# Directory contains more than 1000 articles
# [1997, 8]
# Directory contains more than 1000 articles
# [1997, 9]
# Directory contains more than 1000 articles
# [1997, 10]
# Directory contains more than 1000 articles
# [1997, 11]
# Directory contains more than 1000 articles
# [1997, 12]
# Directory contains more than 1000 articles
# [1998, 1]
# Directory contains more than 1000 articles
# [1998, 2]
# Directory contains more than 1000 articles
# [1998, 3]
# Directory contains more than 1000 articles
# [1998, 4]
# Directory contains more than 1000 articles
# [1998, 5]
# Directory contains more than 1000 articles
# [1998, 6]
# ...
